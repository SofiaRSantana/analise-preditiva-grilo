# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os 
import dotenv
import requests
import pandas as pd
import time

# %% [markdown]
# ## Caminho da pasta

# %%
base_path = "my_spotify_songs"

# %%
dotenv.load_dotenv()

client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')

API_KEY = os.getenv('API_KEY')
BASE_URL = "http://ws.audioscrobbler.com/2.0/"

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret=client_secret))

# %% [markdown]
# ## Funções

# %%
session = requests.Session()

# %%
def buscar_tags(params):
    response = session.get(BASE_URL, params=params)
    return response.json()

# %%
def get_genre_by_name(artista):
    
    # tenta pelas tags do artista
    params_artist = {
        "method": "artist.getTopTags",
        "artist": artista,
        "api_key": API_KEY,
        "format": "json"
    }
    
    data_artist = buscar_tags(params_artist)
    
    try:
        tags = data_artist["toptags"]["tag"]
        return tags[0]['name']   
    except:
        return None

# %%
def get_genre_by_artist(artist):

    artist_info = sp.search(
        q = artist,
        type= 'artist',
        limit= 1
        )

    try:
        genero =  artist_info['artists']['items'][0]['genres'][0]
        return genero
    except IndexError:
        return None

# %%
def get_genre(artista):
    genero = get_genre_by_artist(artista)
    if genero:
        return genero
    
    return get_genre_by_name(artista)

# %% [markdown]
# ## Lógica de criação do DF

# %%
dfs = []

files  = os.listdir(base_path)
# Percorrendo arquivos
for file in files:
    if file.startswith("Streaming_History_Audio") and file.endswith(".json"):
        file_path = os.path.join(base_path, file)
        
        df_temp = pd.read_json(file_path)
        dfs.append(df_temp)

df = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# #### ATENÇÃO!!!!  Vai demorar (Ou não)

# %%
df = df.dropna(subset=['spotify_track_uri', 'master_metadata_album_artist_name'])
df['ts'] = pd.to_datetime(df['ts'])
df = df[df['ts'] >= '2023-01-01']

# %%
df_unico = df[['master_metadata_album_artist_name']]
df_unico = df_unico.drop_duplicates()

# %%
df_unico = df[['master_metadata_album_artist_name']]
df_unico = df_unico.drop_duplicates()


df_unico['genero'] = df_unico.apply(
    lambda row: get_genre(
        row['master_metadata_album_artist_name']
    ), 
    axis=1
)

display(df_unico)
# Out:
#       master_metadata_album_artist_name            genero
# 2168                               Teto    brazilian trap
# 2170                       MC Cabelinho    brazilian trap
# 2171                           Dfideliz    brazilian trap
# 2172                          Aka Rasta    brazilian trap
# 2173                             DNASTY    brazilian trap
# ...                                 ...               ...
# 24589                      Foo Fighters              rock
# 24591                       The Killers  alternative rock
# 24605                   Duncan Laurence               pop
# 24611         Everybody Loves an Outlaw               USA
# 24615                   Jerry Lee Lewis        rockabilly
#
# [1019 rows x 2 columns]

# %%
df_final = pd.merge(
    df,
    df_unico,
    how= 'inner',
    on= 'master_metadata_album_artist_name'
)

# %%
display(df_final)
# Out:
#                              ts platform  ms_played conn_country  \
# 0     2023-01-10 14:08:28+00:00  android       4466           BR
# 1     2023-01-10 14:11:37+00:00  android     178879           BR
# 2     2023-01-10 14:16:55+00:00  android     217539           BR
# 3     2023-01-10 14:21:37+00:00  android     161311           BR
# 4     2023-01-10 14:29:10+00:00  android     150932           BR
# ...                         ...      ...        ...          ...
# 22424 2026-02-02 23:45:30+00:00  android     166028           BR
# 22425 2026-02-02 23:47:37+00:00  android     126346           BR
# 22426 2026-02-02 23:51:09+00:00  android     212353           BR
# 22427 2026-02-02 23:54:49+00:00  android     219320           BR
# 22428 2026-02-02 23:58:24+00:00  android     214653           BR
#
#                                 ip_addr  \
# 0                        187.122.59.170
# 1                        187.122.59.170
# 2                        187.122.59.170
# 3                        187.122.59.170
# 4                        187.122.59.170
# ...                                 ...
# 22424  2804:214:8603:1d1f:1:0:3af4:9fdd
# 22425  2804:214:8603:1d1f:1:0:3af4:9fdd
# 22426  2804:214:8603:1d1f:1:0:3af4:9fdd
# 22427  2804:214:8603:1d1f:1:0:3af4:9fdd
# 22428  2804:214:8603:1d1f:1:0:3af4:9fdd
#
#                          master_metadata_track_name  \
# 0                                     Mustang Preto
# 1                                     Mustang Preto
# 2                                        VALHO NADA
# 3                                         Progresso
# 4                                       Romântico 2
# ...                                             ...
# 22424                     Head & Heart (feat. MNEK)
# 22425                                   Look At Me!
# 22426             INDUSTRY BABY (feat. Jack Harlow)
# 22427                                          Work
# 22428  Another One Bites The Dust - Remastered 2011
#
#       master_metadata_album_artist_name master_metadata_album_album_name  \
# 0                                  Teto                    Mustang Preto
# 1                                  Teto                    Mustang Preto
# 2                          MC Cabelinho                      LITTLE LOVE
# 3                              Dfideliz                        Progresso
# 4                             Aka Rasta                             ZIMA
# ...                                 ...                              ...
# 22424                        Joel Corry        Head & Heart (feat. MNEK)
# 22425                      XXXTENTACION                      Look At Me!
# 22426                         Lil Nas X                          MONTERO
# 22427                           Rihanna                             ANTI
# 22428                             Queen                         The Game
#
#                           spotify_track_uri episode_name  ...  \
# 0      spotify:track:6Vgn3IEUkWs3d6og029Gtm         None  ...
# 1      spotify:track:6Vgn3IEUkWs3d6og029Gtm         None  ...
# 2      spotify:track:18XOY618zQH4bFw3TgVT9L         None  ...
# 3      spotify:track:0tLRlU39HHqJ2BX4DN4qnm         None  ...
# 4      spotify:track:6OPqR2PJZpPlWVZ4IOyljf         None  ...
# ...                                     ...          ...  ...
# 22424  spotify:track:6cx06DFPPHchuUAcTxznu9         None  ...
# 22425  spotify:track:7floNISpH8VF4z4459Qo18         None  ...
# 22426  spotify:track:5Z9KJZvQzH6PFmb8SNkxuk         None  ...
# 22427  spotify:track:72TFWvU3wUYdUuxejTTIzt         None  ...
# 22428  spotify:track:5vdp5UmvTsnMEMESIF2Ym7         None  ...
#
#       audiobook_chapter_uri audiobook_chapter_title  reason_start  reason_end  \
# 0                       NaN                     NaN       appload      logout
# 1                       NaN                     NaN       appload   trackdone
# 2                       NaN                     NaN     trackdone   trackdone
# 3                       NaN                     NaN     trackdone   trackdone
# 4                       NaN                     NaN    trackerror   trackdone
# ...                     ...                     ...           ...         ...
# 22424                   NaN                     NaN     trackdone   trackdone
# 22425                   NaN                     NaN     trackdone   trackdone
# 22426                   NaN                     NaN     trackdone   trackdone
# 22427                   NaN                     NaN     trackdone   trackdone
# 22428                   NaN                     NaN     trackdone   trackdone
#
#        shuffle  skipped offline offline_timestamp  incognito_mode  \
# 0         True    False   False      1.673360e+09           False
# 1         True    False   False      1.673360e+09           False
# 2         True    False   False      1.673360e+09           False
# 3         True    False   False      1.673360e+09           False
# 4         True    False   False      1.673361e+09           False
# ...        ...      ...     ...               ...             ...
# 22424     True    False   False      1.770076e+09            True
# 22425     True    False   False      1.770076e+09            True
# 22426     True    False   False      1.770076e+09            True
# 22427     True    False   False      1.770076e+09            True
# 22428     True    False   False      1.770076e+09            True
#
#                genero
# 0      brazilian trap
# 1      brazilian trap
# 2      brazilian trap
# 3      brazilian trap
# 4      brazilian trap
# ...               ...
# 22424       dance pop
# 22425         emo rap
# 22426         Hip-Hop
# 22427             pop
# 22428    classic rock
#
# [22429 rows x 24 columns]

# %% [markdown]
# ## Salvando na maquina

# %%
df_final.to_csv('spotify_songs.csv', index=False)
